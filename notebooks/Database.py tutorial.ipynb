# %% [markdown]
# # Database.py tutorial
#
# This tutorial describes the functionality of the 'database' subpackage of the PAA repo. The subpackage incorporates the SubstrateDatabase class that provides a framework to load and query datasets of protease-substrate activity.
#
# To demo the package, we will load and query a rich dataset of 150 unique peptide substrates and their cleavage susceptibility against a diverse set of recombinant proteases, generated in the Bhatia Lab. All input files required query said datasets are made publically available and should comprise a valuable research for the sceintific community.
#
# The **SubstrateDatabase class** enables to:
# - Query protease-substrate activity assay data for proteases, substrates, or sequences of itnerest
# - Identification of the substrates present in the database that are most robustly and specifically cleaved by a protease of interest
# - Identification of the proteases that robustly and/or specifically cleave a peptide substrate of interest
# - Assessment of the degree of similarity between a sequence of interest and sequences in the database
# - Assessment of degree of similarity between all substrates in the database
# - Search for k-mer motifs across all sequences in the database

# %% [markdown]
# We will first import all necessary packages

# %%
pwd
# Out:
# '/Users/mariaalonso/Work/protease_activity_analysis/notebooks'

# %%
cd ..
# Out:
# /Users/mariaalonso/Work/protease_activity_analysis

# %%
import protease_activity_analysis as paa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# Next, we will define arguments to the SubstrateDatabase class. These are the user-defined inputs to the function:
# - **data_files** : Input .csv files containing recombinant screening data to be incorported in the database. Here we will load 6 retrospective recombinant screen datafiles generated in the Bhatia Lab by screening different susbtrate libraries agianst a suit or recombinant proteases. Alternate datafiles to the ones presented here can be loaded with this class. The input .csv should consist of a matrix of substrates (rows) by proteases/samples (columns) with cells corresponding to some cleavage efficiency metric, data need not be normalized.
# - **sequence_file**: .csv file containing all peptide sequences and peptide names for screened substrates. This file will chnage as a function of the data_files loaded.
# - **names_file**: .pkl file that maps all names given to the same sequence to a unified substrate name. This is particularly relevant when more than one name is given to a unique sequence. This file will chnage as a function of the data_files loaded.
# - **aa_dict_file**: .pkl file that maps amino acids to different colors using the RasMol 'shapely' color scheme, based on Robert Fletterick’s “Shapely models.” This generalizes across any input files but alternative color codes can be loaded by the user as desired.
#
# We will also define an output directory **db_dir** to save output files generated.

# %%
# Define input files
data_files = ['data/screens/PAA/PAA_screens/Bhatia1_PAA.csv', 'data/screens/PAA/PAA_screens/Bhatia2_PAA.csv', 
             'data/screens/PAA/PAA_screens/Bhatia3_PAA.csv', 'data/screens/PAA/PAA_screens/Bhatia4_PAA.csv',
             'data/screens/PAA/PAA_screens/Bhatia5_PAA.csv', 'data/screens/PAA/PAA_screens/Bhatia6_PAA.csv']
sequence_file = 'data/screens/PAA/Peptide_Inventory_150.csv'
names_file = 'data/screens/PAA/names_dict.pkl'
aa_dict_file = 'data/screens/PAA/aa_dict_color_matched.pkl'

# Define output directory
db_dir = 'outputs/DatabaseTutorial'

# %% [markdown]
# ## Exploring the SubstrateDatabase class
# We will now create a new instance of the SubstrateDatabase class and assign this object to the local variable data.

# %%
# Load all relevant screening data from screens of interest
data = paa.database.SubstrateDatabase(data_files, sequence_file, names_file, aa_dict_file)

# %% [markdown]
# In instantiating the SubstrateDatabase class, the raw data is automatically processed and formatted to enable streamline searching by protease, substrate or sequence of interest:
#
# - All raw activity data across input screens in loaded and zscored
# - Proteases and substrates in each screen are identified
# - Sequence data for each substrate is loaded
# - Name maps for each substrate are loaded
#
#
# We can explore the processed data using different methods of the SubstrateDatabase class as illustrated below:

# %%
# Get names of screens being queried
names = data.screen_names
names
# Out:
# ['Bhatia1_PAA',
#  'Bhatia2_PAA',
#  'Bhatia3_PAA',
#  'Bhatia4_PAA',
#  'Bhatia5_PAA',
#  'Bhatia6_PAA']

# %%
# Visualize screen metadata
data.summarize_screen(data.screen_names)
# Out:
# /Users/mariaalonso/Work/protease_activity_analysis/protease_activity_analysis/database.py:498: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
# Protease rPLPro not found
# Protease r3CLpro not found
#         Screen # Peptides # Proteases Metallo Aspartic Cysteine Serine
# 0  Bhatia1_PAA         15          15       6        2        0      7
# 1  Bhatia2_PAA         58          22      10        0        1     11
# 2  Bhatia3_PAA         72          22      10        0        0     12
# 3  Bhatia4_PAA         20          21       3        1        3     12
# 4  Bhatia5_PAA         78          26      11        1        2     12
# 5  Bhatia6_PAA         83          37      20        2        3     12

# %%
# View all available proteases for particular screen 
prot = data.get_screen_proteases('Bhatia1_PAA')
prot
# Out:
# ['MMP1',
#  'MMP3',
#  'MMP11',
#  'MMP12',
#  'MMP13',
#  'PRSS22',
#  'PRSS3',
#  'PRSS8',
#  'ACE2',
#  'F7',
#  'NAPSA',
#  'CTSD',
#  'KLK6',
#  'KLK13',
#  'KLK14']

# %%
unique_prot = []
for screen in names:
    prot = data.get_screen_proteases(screen)
    unique_prot.append(prot)
unique_prot = set(np.concatenate(unique_prot, axis=0))
print('Number of unique proteases in database:', len(unique_prot))
unique_prot
# Out:
# Number of unique proteases in database: 77
# {'ACE2',
#  'ADAM12',
#  'ADAM28',
#  'ADAM8',
#  'ADAM9',
#  'ADAMTS1',
#  'ADAMTS15',
#  'CASP1',
#  'CTSA',
#  'CTSB',
#  'CTSD',
#  'CTSE',
#  'CTSG',
#  'CTSK',
#  'CTSS',
#  'CTSZ',
#  'ELANE',
#  'F10',
#  'F2',
#  'F7',
#  'F9',
#  'FAP',
#  'FURIN',
#  'GZMA',
#  'GZMB',
#  'GZMH',
#  'GZMK',
#  'HAT',
#  'HGFAC',
#  'HPN',
#  'HTRA1',
#  'KLK1',
#  'KLK11',
#  'KLK12',
#  'KLK13',
#  'KLK14',
#  'KLK2',
#  'KLK3',
#  'KLK4',
#  'KLK5',
#  'KLK6',
#  'KLK8',
#  'LGMN',
#  'MME',
#  'MMP1',
#  'MMP10',
#  'MMP11',
#  'MMP12',
#  'MMP13',
#  'MMP14',
#  'MMP15',
#  'MMP17',
#  'MMP19',
#  'MMP2',
#  'MMP24',
#  'MMP26',
#  'MMP3',
#  'MMP7',
#  'MMP8',
#  'MMP9',
#  'NAPSA',
#  'PAPPA',
#  'PAPPA2',
#  'PCSK1',
#  'PCSK2',
#  'PLAT',
#  'PLAU',
#  'PRSS1',
#  'PRSS2',
#  'PRSS22',
#  'PRSS3',
#  'PRSS8',
#  'PRTN3',
#  'ST14',
#  'TMPRSS11E',
#  'r3CLpro',
#  'rPLPro'}

# %%
# Generate a map of recombinant proteases and their corresponding protease class
spec_dict = data.get_protease_class('Bhatia1_PAA')
spec_dict
# Out:
#    Protease     Class
# 0      MMP1   Metallo
# 1      MMP3   Metallo
# 2     MMP11   Metallo
# 3     MMP12   Metallo
# 4     MMP13   Metallo
# 5    PRSS22    Serine
# 6     PRSS3    Serine
# 7     PRSS8    Serine
# 8      ACE2   Metallo
# 9        F7    Serine
# 10    NAPSA  Aspartic
# 11     CTSD  Aspartic
# 12     KLK6    Serine
# 13    KLK13    Serine
# 14    KLK14    Serine

# %%
# View all available substrates for particular screen 
data.get_screen_substrates('Bhatia1_PAA')
# Out:
# ['S16',
#  'S19',
#  'S22',
#  'S24',
#  'S4',
#  'S51',
#  'S71',
#  'S72',
#  'S73',
#  'S74',
#  'S75',
#  'S76',
#  'S77',
#  'S78',
#  'S79']

# %% [markdown]
# ## Searching for a protease of interest
# Beyond exploring the contents stored in **data** we can query the dataset for a protease of interest, we will exemplify the main protease-search functionalities using MMP13.
#
# - **data.search_protease('MMP13', z_threshold=2, out_dir=db_dir, plot_hist=True)**: will give you an overview of the screening data available across sscreens for a protease of interest. It will determine which screens contain data against the protease of interest, generate a histogram of z-score distributions for all substrates against the protease of interest, and return a DataFrame containing substrates with z-score higher than the user-defined z-score threshold.
# - **data.get_top_hits('MMP13', 'protease', top_k=3, out_dir=db_dir, z_threshold=None)**: will retrieve the top cleaved substrates for a protease of interest as defined by a k- **or** z-score threshold. It will also retrieve and print the z-scores and sequences (color-coded by RasMol shapely colors) of the top cleaved substrates to help interpret hits. It will also return data for individual screens as well as across all screens.
# - **data.specificity_analysis(db_dir, protease='MMP13', substrate=None, threshold=4, plot=True, cmap=True)**: queries the specificity of a protease of interest by generating **specificty plots** for each screen in which a protease of interest was included. Substrates scoring high along the x-axis and y-axis are efficiently and specifically cleaved, respectively, by the protease of interest. **Note** that all cleavage efficiency and specificity measures are relative to the other substrates and proteases in the screen. Raw cleavage values are overlaid using a color map to help interpret z-scores. Substrates with z-score>z_threshold in either axis will be labelled.

# %%
# For a protease of interest find all relevant screening data. Can set a z-score or k- threshold
mmp13_df = data.search_protease('MMP13', z_threshold=2, out_dir=db_dir, plot_hist=True)

# Visualize result from search protease with z_threshold>2
display(mmp13_df)
# Out:
# MMP13 found in Bhatia1_PAA
# MMP13 found in Bhatia2_PAA
# MMP13 found in Bhatia3_PAA
# MMP13 found in Bhatia5_PAA
# MMP13 found in Bhatia6_PAA
#       Bhatia1_PAA  Bhatia2_PAA  Bhatia3_PAA  Bhatia5_PAA  Bhatia6_PAA
# S110          NaN     2.064783          NaN     2.696652          NaN
# S111          NaN     2.103476          NaN          NaN          NaN
# S118          NaN          NaN          NaN     2.541186     4.305619
# S131          NaN          NaN          NaN     2.208370          NaN
# S24           NaN          NaN          NaN     3.237900          NaN
# S4            NaN          NaN     2.690430          NaN          NaN
# S7            NaN          NaN          NaN     2.682638          NaN
# S71           NaN     4.479478          NaN          NaN          NaN
# S73           NaN          NaN     2.110120          NaN          NaN
# S76           NaN          NaN     3.125480     4.637912     4.999768
# S77           NaN          NaN     2.785605          NaN          NaN
# S78      2.469211          NaN          NaN          NaN          NaN
# S79           NaN     3.085757          NaN          NaN          NaN
# S8            NaN          NaN     2.639814          NaN          NaN

# %%
# Get top cleaved substrates for protease of interest
MMP13_individual, MMP13_overall = data.get_top_hits('MMP13', 'protease', top_k=5, out_dir=db_dir, z_threshold=None)

display(MMP13_overall)
# Out:
# MMP13 found in Bhatia1_PAA
# MMP13 found in Bhatia2_PAA
# MMP13 found in Bhatia3_PAA
# MMP13 found in Bhatia5_PAA
# MMP13 found in Bhatia6_PAA
# Top hits for MMP13 in Bhatia1_PAA:
#
# S78 : GGP[Cha]G[Cys(Me)]HAGC - GGP[Cha]G[Cys(Me)]HAGC
#
# S4 : GPLGLRSWG - GPLGLRSWG
#
# S77 : GAPFEMSAG - GAPFEMSAG
#
# S79 : GGPVGLIG - GGPVGLIG
#
# S76 : GPLGMRG - GPLGMRG
#
# Top hits for MMP13 in Bhatia2_PAA:
# S71 : GGPQGIWGQ - GGPQGIWGQ
#
# S79 : GGPVGLIG - GGPVGLIG
#
# S111 : GSPLAQAVRSSG - GSPLAQAVRSSG
#
#
# S110 : GLAQA[Phe(homo)]RSG - GLAQA[Phe(homo)]RSG
#
# S4 : GPLGLRSWG - GPLGLRSWG
#
# Top hits for MMP13 in Bhatia3_PAA:
# S76 : GPLGMRG - GPLGMRG
#
# S77 : GAPFEMSAG - GAPFEMSAG
#
# S4 : GPLGLRSWG - GPLGLRSWG
#
# S8 : GPLGLRG - GPLGLRG
#
# S73 : GGPLGVRGK - GGPLGVRGK
#
# Top hits for MMP13 in Bhatia5_PAA:
# S76 : GPLGMRG - GPLGMRG
#
# S24 : GRPLALWESQG - GRPLALWESQG
#
#
# S110 : GLAQA[Phe(homo)]RSG - GLAQA[Phe(homo)]RSG
#
# S7 : GPLGFRVG - GPLGFRVG
#
# S118 : GAPFEFSAG - GAPFEFSAG
#
# Top hits for MMP13 in Bhatia6_PAA:
# S76 : GPLGMRG - GPLGMRG
#
# S118 : GAPFEFSAG - GAPFEFSAG
#
#
# S110 : GLAQA[Phe(homo)]RSG - GLAQA[Phe(homo)]RSG
#
# S30 : GPRPFNYLG - GPRPFNYLG
#
#
# S78 : GGP[Cha]G[Cys(Me)]HAGC - GGP[Cha]G[Cys(Me)]HAGC
#
# Top hits for MMP13 overall. Hit, Source, Score:
# S76, Bhatia6_PAA, 5.00
# S76, Bhatia5_PAA, 4.64
# S71, Bhatia2_PAA, 4.48
# S118, Bhatia6_PAA, 4.31
# S24, Bhatia5_PAA, 3.24
#          Scores       Source     Sequence
# index
# S76    4.999768  Bhatia6_PAA      GPLGMRG
# S76    4.637912  Bhatia5_PAA      GPLGMRG
# S71    4.479478  Bhatia2_PAA    GGPQGIWGQ
# S118   4.305619  Bhatia6_PAA    GAPFEFSAG
# S24    3.237900  Bhatia5_PAA  GRPLALWESQG

# %%
# Query the specificity of a protease of interest across all screens in the database.e.g. MMP13
data.specificity_analysis(db_dir, protease='ST14', substrate=None, threshold=1, plot=True, cmap=True)
# Out:
# ST14 found in Bhatia4_PAA
# ST14 found in Bhatia6_PAA

# %% [markdown]
# ## Searching for a substrate of interest
#
# In order to facilitate the search for a substrate of interest it is important to map back and forth between substrate names and sequences. To this end, we provide two useful functions:
# - **data.get_sequence_of_name('PP15')**: maps substrate name to sequence
# - **data.get_name_of_sequence('GGGSGRSANAKG'**): maps a sequence of interest to all given names for this sequence

# %%
# View sequence for substrates of interest
data.get_sequence_of_name('PP15')
# Out:
# 'GRPLALWESQG'

# %%
# View name of substrates of interest
data.get_name_of_sequence('GGGSGRSANAKG')
# Out:
# (15    S16
#  Name: Name, dtype: object,
#  15    [PP08, PQ2, LQ20, BV08, TQ39]
#  Name: Names, dtype: object)

# %% [markdown]
# If the sequence is not identical to any of the substrates screened in the database, we can search for similar substrates using the **data.find_similar_substrates** function.
#
# Here we demonstrate this by looking up the 5 most similar substrates to 'GGPLG' as defined by the 'Partial Similarity Ratio'.

# %%
# Return the top 5 most similar substrates in the database to substarte of interest ('GGPLG')
sim_m_sorted, top_k = data.find_similar_substrates('GGPLG', True, 'Partial Similarity Ratio', 5)
top_k
# Out:
# Queried seq:
# GGPLG - GGPLG
#
# S94:GGPLGLRWW - GGPLGLRWW
#
# S73:GGPLGVRGK - GGPLGVRGK
#
# S57:GGGPLGLARG - GGGPLGLARG
#
# S76:GPLGMRG - GPLGMRG
#
# S138:GGHPGGPQG - GGHPGGPQG
#      Name    Sequence Composition  Similarity Ratio  Partial Similarity Ratio
# 93    S94   GGPLGLRWW     Natural                71                       100
# 72    S73   GGPLGVRGK     Natural                71                       100
# 56    S57  GGGPLGLARG     Natural                67                       100
# 75    S76     GPLGMRG     Natural                67                        80
# 137  S138   GGHPGGPQG     Natural                57                        80

# %% [markdown]
# Once we have identified the name of the substrate we want to look up, we can query the dataset for a substrate of interest. We will exemplify the main protease-search functionalities using S4. Parallel functions to those described for searching for a protease are avialable for substrates, namely:
#
# - **data.get_top_hits**. Find top k or proteases with z-score>z-threshold in any screen for substrate of interest. Both individual and overall top proteases are returned.
# - **data.specificity_analysis**. In this plot, each point represent a protease in the screen. Proteases scoring high along the x-axis cleave S4 efficiently. Proteases scoring high along the y-axis score S4 specifically over other substrates in the screen. In addition to overlaying a color map of absolute cleavage values, proteases with z-scores>z-threshold in either ecis are color-coded by protease class.

# %%
# Get top hits for protease that most efficiently cleave peptide of interest
S4_individual, S4_overall = data.get_top_hits('S5', 'substrate', top_k=3, out_dir=None, z_threshold=None)
# Out:
# S5 found in Bhatia3_PAA
# Top hits for S5 in Bhatia3_PAA:
# TMPRSS11E
# PRSS2
# PCSK1
# Top hits for S5 overall. Hit, Source, Score:
# TMPRSS11E, Bhatia3_PAA, -0.00
# PRSS2, Bhatia3_PAA, -0.24
# PCSK1, Bhatia3_PAA, -0.28

# %%
# Query the specificity of a substrate of interest across all screens in the database.e.g. S4
data.specificity_analysis(db_dir, protease=None, substrate='S51', threshold=1, plot=True, cmap=True)
# Out:
# S51 found in Bhatia1_PAA
# S51 found in Bhatia2_PAA
# S51 found in Bhatia3_PAA
# S51 found in Bhatia5_PAA
# S51 found in Bhatia6_PAA

# %% [markdown]
# To use this function to help interpret data from an in vivo experiment, we will generate specificity plots for substrates that were found to be differentially cleaved in KP mice at 7.5 weeks, namely:
# - PP02, PP03, PP09 and PP12: preferentially cleaved in KP mice
# - PP06: preferentially cleaved in healthy control mice

# %%
# Query specificity of PP02, PP03, PP06, PP09 and PP12

sub_list = ['PP02', 'PP03', 'PP06', 'PP09', 'PP12']

for sub in sub_list:
    data.specificity_analysis(db_dir, protease=None, substrate=sub, threshold=2, plot=True, cmap=True)
# Out:
# Searching by alternative names...
# Substrate found under unified name S79
# S79 found in Bhatia1_PAA
# S79 found in Bhatia2_PAA
# S79 found in Bhatia5_PAA
# S79 found in Bhatia6_PAA
# Searching by alternative names...
# Substrate found under unified name S72
# S72 found in Bhatia1_PAA
# S72 found in Bhatia2_PAA
# S72 found in Bhatia3_PAA
# S72 found in Bhatia5_PAA
# S72 found in Bhatia6_PAA
# Searching by alternative names...
# Substrate found under unified name S74
# S74 found in Bhatia1_PAA
# S74 found in Bhatia2_PAA
# S74 found in Bhatia3_PAA
# S74 found in Bhatia4_PAA
# S74 found in Bhatia5_PAA
# S74 found in Bhatia6_PAA
# Searching by alternative names...
# Substrate found under unified name S22
# S22 found in Bhatia1_PAA
# S22 found in Bhatia2_PAA
# S22 found in Bhatia3_PAA
# S22 found in Bhatia5_PAA
# S22 found in Bhatia6_PAA
# Searching by alternative names...
# Substrate found under unified name S76
# S76 found in Bhatia1_PAA
# S76 found in Bhatia3_PAA
# S76 found in Bhatia4_PAA
# S76 found in Bhatia5_PAA
# S76 found in Bhatia6_PAA
# /Users/mariaalonso/Work/protease_activity_analysis/protease_activity_analysis/database.py:754: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# ## Streamlining the search for several proteases or substrates of interest

# %% [markdown]
# To easily determine whether lists of proteases or substartes of interest were included in at least one of the screens, we have also implemented **data.find_proteases(prot_list)**  and **data.find_substrates(subs_list)** methods to the class.
#
# **Notes**:
# - **data.find_proteases(prot_list)**: protease names are stored with human genes names as all proteases screened were human recombinant proteases. In the example below, all but Cathepsin H were included in at least one of the screens.
# - **data.find_substrates(subs_list)**: substrate names correspond to substrate names given by trainees in the Bhatia Lab and as available in our published work. If multiple names exist for a given substrate, the class will use 'names_file' to ensure it identifies all given names for a substarte of interest and maps it to the unified name (encoded from S1-S150) used in the SubstrateDatabase instance.

# %%
# Check whether proteases of interest are in the dataset
prot_list = ['MMP13', 'MMP15', 'CTSB', 'CTSH']

found_prot = data.find_proteases(prot_list)
print(found_prot)
# Out:
# CTSH not found in database
# ['MMP13', 'MMP15', 'CTSB']

# %%
# Check whether substrates of interest are in the dataset
subs_list = [ 'PQ1', 'S2', 'S300']

found_sub = data.find_substrates(subs_list)
print(found_sub)
# Out:
# Substrate PQ1 is encoded by S26
# Substrate S300 not found
# ['S26', 'S2']

# %% [markdown]
# # Explore sequence diversity of substrate library
# In interpreting data from recombinant protease screens or activity assays it is important to have an understanding of the diversity in sequence space of substrates screened and the degree of overlap between substrates of interest.
#
# As metrics of similarity in sequence space, we have implemented functions that support two different metrics of sequence similarity:
# - **String similarity** as a function of edit distace is supported by **data.get_similarity_matrix()**. The function will compute pairwise similarity scores, as defined by the 'Levenschtein edit distance' or the 'Modified Levenschtein edit distance' between all substrates in the database and perform hierarchical clustering on said similarity scores. In this way, substrates that cluster together in the heatmap will share a high degree of sequence similarity. Pariwise similarity matrices as DataFrames are also returned.
# - **kmer-related analyses** are supported by a range of functions including:
# - **data.run_kmer_analysis([3,4,5,6,7,8])**: generates all kmers of lengths 3-8 for all substrates in the dataset
# - **data.get_kmer_dict(4)**: allows to query kmer dictionary of length k (e.g.4)
# - **data.get_kmer_overlap(4)**: for each kmer of length k (e.g.4) find all substrates that contain said kmer
# - **data.summarize_kmer(kmer_len = 3, top_k = 20)**: return kmer distribution and return top k ovver-represented kmers
# - **data.search_kmer('PLGL', True, data.aa_dict)**:

# %%
# Generate pairwise similarity matrix between all peptides of in the database
sim_m, sim_par_m, clus_sim, clus_sim_p = data.get_similarity_matrix(out_dir=db_dir)
display(sim_m)
# Out:
# /Users/mariaalonso/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:659: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
# /Users/mariaalonso/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:659: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#          S1     S2     S3     S4     S5    S6    S7    S8    S9   S10  ...  \
# S1    100.0   78.0   89.0   33.0   30.0  40.0  47.0  38.0  20.0  40.0  ...
# S2     78.0  100.0   78.0   33.0   50.0  50.0  47.0  38.0  30.0  40.0  ...
# S3     89.0   78.0  100.0   33.0   40.0  50.0  47.0  38.0  30.0  40.0  ...
# S4     33.0   33.0   33.0  100.0   50.0  40.0  71.0  88.0  30.0  30.0  ...
# S5     30.0   50.0   40.0   50.0  100.0  45.0  32.0  33.0  27.0  36.0  ...
# ...     ...    ...    ...    ...    ...   ...   ...   ...   ...   ...  ...
# S146   19.0   32.0   26.0   32.0   30.0  36.0  27.0  28.0  30.0  24.0  ...
# S147   32.0   32.0   32.0   42.0   19.0  38.0  44.0  47.0  48.0  38.0  ...
# S148   32.0   32.0   32.0   42.0   29.0  38.0  44.0  47.0  38.0  38.0  ...
# S149   10.0   10.0   10.0   14.0   14.0  18.0  10.0  15.0  14.0  18.0  ...
# S150   38.0   50.0   38.0   38.0   44.0  56.0  53.0  43.0  44.0  44.0  ...
#
#       S141  S142  S143  S144  S145   S146   S147   S148   S149   S150
# S1    32.0  30.0  48.0  36.0  27.0   19.0   32.0   32.0   10.0   38.0
# S2    32.0  30.0  48.0  45.0  27.0   32.0   32.0   32.0   10.0   50.0
# S3    32.0  30.0  38.0  36.0  27.0   26.0   32.0   32.0   10.0   38.0
# S4    42.0  30.0  48.0  45.0  45.0   32.0   42.0   42.0   14.0   38.0
# S5    19.0  18.0  26.0  42.0  33.0   30.0   19.0   29.0   14.0   44.0
# ...    ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# S146  19.0  36.0  29.0  34.0  29.0  100.0   38.0   31.0   36.0   41.0
# S147  50.0  48.0  45.0  35.0  26.0   38.0  100.0   70.0   14.0   35.0
# S148  60.0  38.0  45.0  43.0  43.0   31.0   70.0  100.0   14.0   35.0
# S149  19.0  32.0  13.0  30.0  17.0   36.0   14.0   14.0  100.0   15.0
# S150  35.0  33.0  32.0  50.0  30.0   41.0   35.0   35.0   15.0  100.0
#
# [150 rows x 150 columns]

# %%
# Run kmer analysis on dataset for kmer lengths of interest [3,4,5,6,7,8]
data.run_kmer_analysis([3,4,5,6,7,8])
# Out:
# For k= 3
# Number of unique kmers is: 728
# For k= 4
# Number of unique kmers is: 827
# For k= 5
# Number of unique kmers is: 758
# For k= 6
# Number of unique kmers is: 659
# For k= 7
# Number of unique kmers is: 541
# For k= 8
# Number of unique kmers is: 413

# %%
# Retrieve relevant kmer_dict for k=4, keys are substrates and keys are all possible consecutive kmers of k=4 length
data.get_kmer_dict(4)
# Out:
# {'S1': ['GRQR', 'RQRR', 'QRRV', 'RRVV', 'RVVG', 'VVGG'],
#  'S2': ['GRQA', 'RQAR', 'QARA', 'ARAV', 'RAVG', 'AVGG'],
#  'S3': ['GRRA', 'RRAR', 'RARV', 'ARVV', 'RVVG', 'VVGG'],
#  'S4': ['GPLG', 'PLGL', 'LGLR', 'GLRS', 'LRSW', 'RSWG'],
#  'S5': ['GWEA', 'WEAV', 'EAVR', 'AVRS', 'VRSA', 'RSAM', 'SAMW', 'AMWG'],
#  'S6': ['GWIG', 'WIGF', 'IGFR', 'GFRN', 'FRNA', 'RNAG', 'NAGA', 'AGAG'],
#  'S7': ['GPLG', 'PLGF', 'LGFR', 'GFRV', 'FRVG'],
#  'S8': ['GPLG', 'PLGL', 'LGLR', 'GLRG'],
#  'S9': ['GATP', 'ATPK', 'TPKI', 'PKIF', 'KIFN', 'IFNT', 'FNTE', 'NTEG'],
#  'S10': ['GETR', 'ETRI', 'TRII', 'RIIK', 'IIKG', 'IKGF', 'KGFE', 'GFEG'],
#  'S11': ['GPLA', 'PLAL', 'LALW', 'ALWA', 'LWAR', 'WARG'],
#  'S12': ['GALV', 'ALVP', 'LVPR', 'VPRG', 'PRGS', 'RGSA', 'GSAG'],
#  'S13': ['GGLV', 'GLVP', 'LVPR', 'VPRG', 'PRGS', 'RGSG'],
#  'S14': ['GRQA', 'RQAR', 'QARQ', 'ARQV', 'RQVG', 'QVGG'],
#  'S15': ['GLQA', 'LQAR', 'QARV', 'ARVV', 'RVVG', 'VVGG'],
#  'S16': ['GGGS',
#   'GGSG',
#   'GSGR',
#   'SGRS',
#   'GRSA',
#   'RSAN',
#   'SANA',
#   'ANAK',
#   'NAKG'],
#  'S17': ['GGVP', 'GVPR', 'VPRG', 'PRGG'],
#  'S18': ['GRQS', 'RQSR', 'QSRI', 'SRIV', 'RIVG', 'IVGG', 'VGGG'],
#  'S19': ['GILS', 'ILSR', 'LSRI', 'SRIV', 'RIVG', 'IVGG', 'VGGG'],
#  'S20': ['GGRK', 'GRKR', 'RKRK', 'KRKV', 'RKVG', 'KVGG', 'VGGS', 'GGSG'],
#  'S21': ['GDEK',
#   'DEKG',
#   'EKGK',
#   'KGKA',
#   'GKAR',
#   'KARD',
#   'ARDF',
#   'RDFF',
#   'DFFG'],
#  'S22': ['GKPI', 'KPIS', 'PISL', 'ISLI', 'SLIS', 'LISS', 'ISSG'],
#  'S23': ['GLAQ', 'LAQA', 'AQAF', 'QAFR', 'AFRS', 'FRSG'],
#  'S24': ['GRPL', 'RPLA', 'PLAL', 'LALW', 'ALWE', 'LWES', 'WESQ', 'ESQG'],
#  'S26': ['GRQR', 'RQRR', 'QRRA', 'RRAL', 'RALE', 'ALEK', 'LEKG'],
#  'S27': ['GIQQ', 'IQQR', 'QQRS', 'QRSL', 'RSLG', 'SLGG', 'LGGG'],
#  'S28': ['GLRG',
#   'LRGG',
#   'RGGK',
#   'GGKG',
#   'GKGG',
#   'KGGP',
#   'GGPP',
#   'GPPP',
#   'PPPP',
#   'PPPG'],
#  'S29': ['GGGA', 'GGAP', 'GAPF', 'APFE', 'PFEM', 'FEMS', 'EMSA'],
#  'S30': ['GPRP', 'PRPF', 'RPFN', 'PFNY', 'FNYL', 'NYLG'],
#  'S31': ['GAGP', 'AGPR', 'GPRK', 'PRKA', 'RKAA', 'KAAK', 'AAKG'],
#  'S32': ['GAKI', 'AKIR', 'KIRK', 'IRKA', 'RKAK', 'KAKK', 'AKKG'],
#  'S33': ['GAKI', 'AKIR', 'KIRG', 'IRGQ', 'RGQA', 'GQAK', 'QAKG'],
#  'S34': ['GNSG', 'NSGR', 'SGRA', 'GRAV', 'RAVT', 'AVTY', 'VTYG'],
#  'S35': ['GTYS', 'TYSR', 'YSRS', 'SRSR', 'RSRY', 'SRYL', 'RYLG'],
#  'S36': ['GRPK', 'RPKP', 'PKPQ', 'KPQQ', 'PQQF', 'QQFW', 'QFWG'],
#  'S37': ['GMAA',
#   'MAAL',
#   'AALI',
#   'ALIV',
#   'LIVR',
#   'IVRP',
#   'VRPD',
#   'RPDL',
#   'PDLG'],
#  'S38': ['GGRI', 'GRIF', 'RIFL', 'IFLR', 'FLRT', 'LRTA', 'RTAG'],
#  'S39': ['GSGD', 'SGDR', 'GDRM', 'DRMW', 'RMWg', 'MWgg', 'WggG'],
#  'S40': ['GSGE', 'SGER', 'GERM', 'ERMM', 'RMMG', 'MMGg', 'MGgG'],
#  'S41': ['GsDD', 'sDDR', 'DDRR', 'DRRA', 'RRAG', 'RAGg', 'AGgG'],
#  'S42': ['GKLR', 'KLRV', 'LRVV', 'RVVG', 'VVGG', 'VGGH', 'GGHP', 'GHPG'],
#  'S43': ['GMAA',
#   'MAAL',
#   'AALI',
#   'ALIT',
#   'LITR',
#   'ITRP',
#   'TRPD',
#   'RPDF',
#   'PDFG'],
#  'S44': ['GELI',
#   'ELIQ',
#   'LIQR',
#   'IQRN',
#   'QRNL',
#   'RNLS',
#   'NLSP',
#   'LSPA',
#   'SPAG'],
#  'S45': ['GSNL',
#   'SNLT',
#   'NLTR',
#   'LTRI',
#   'TRIV',
#   'RIVG',
#   'IVGG',
#   'VGGQ',
#   'GGQG'],
#  'S46': ['GYQI',
#   'YQIK',
#   'QIKP',
#   'IKPL',
#   'KPLK',
#   'PLKS',
#   'LKST',
#   'KSTD',
#   'STDG'],
#  'S47': ['GNIP',
#   'NIPM',
#   'IPMG',
#   'PMGL',
#   'MGLL',
#   'GLLY',
#   'LLYN',
#   'LYNK',
#   'YNKG'],
#  'S48': ['GPQG', 'PQGR', 'QGRI', 'GRIV', 'RIVG', 'IVGG'],
#  'S49': ['GIKP', 'IKPR', 'KPRI', 'PRIV', 'RIVG', 'IVGG'],
#  'S50': ['GPMK', 'PMKR', 'MKRL', 'KRLT', 'RLTL', 'LTLG'],
#  'S51': ['GGLG', 'GLGP', 'LGPK', 'GPKG', 'PKGQ', 'KGQT', 'GQTG'],
#  'S52': ['GGAG', 'GAGG', 'AGGA', 'GGAQ', 'GAQM', 'AQMG', 'QMGA'],
#  'S53': ['GGAT', 'GATD', 'ATDV', 'TDVT', 'DVTT', 'VTTT', 'TTTP'],
#  'S54': ['GGLS', 'GLSL', 'LSLP', 'SLPE', 'LPET', 'PETG', 'ETGE'],
#  'S55': ['GSPL',
#   'SPLA',
#   'PLAQ',
#   'LAQA',
#   'AQAV',
#   'QAVR',
#   'AVRS',
#   'VRSS',
#   'RSSS'],
#  'S56': ['GSSM',
#   'SSMA',
#   'SMAQ',
#   'MAQT',
#   'AQTL',
#   'QTLT',
#   'TLTL',
#   'LTLR',
#   'TLRS',
#   'LRSS',
#   'RSSS'],
#  'S57': ['GGGP', 'GGPL', 'GPLG', 'PLGL', 'LGLA', 'GLAR', 'LARG'],
#  'S58': ['GMER', 'MERM', 'ERMG', 'RMGG'],
#  'S59': ['GGGG', 'GGGP', 'GGPG', 'GPGG'],
#  'S60': ['GEWW', 'EWWM', 'WWMD', 'WMDY', 'MDYQ', 'DYQG'],
#  'S61': ['GFLR', 'FLRR', 'LRRQ', 'RRQF', 'RQFK', 'QFKV', 'FKVV', 'KVVT'],
#  'S62': ['GVGR', 'VGRP', 'GRPE', 'RPEW', 'PEWW', 'EWWM', 'WWMD', 'WMDG'],
#  'S63': ['GLGA',
#   'LGAL',
#   'GALL',
#   'ALLR',
#   'LLRV',
#   'LRVK',
#   'RVKR',
#   'VKRL',
#   'KRLE'],
#  'S64': ['GLAS', 'LASA', 'ASAS', 'SAST', 'ASTM', 'STMD', 'TMDG'],
#  'S65': ['GGKG', 'GKGR', 'KGRG', 'GRGL', 'RGLS', 'GLSL', 'LSLG'],
#  'S66': ['GHGD', 'HGDQ', 'GDQM', 'DQMA', 'QMAQ', 'MAQK', 'AQKS'],
#  'S67': ['GRAE', 'RAEQ', 'AEQQ', 'EQQR', 'QQRL', 'QRLK', 'RLKG'],
#  'S68': ['GRAE', 'RAEQ', 'AEQQ', 'EQQR', 'QQRL', 'QRLG'],
#  'S69': ['GDQM', 'DQMA', 'QMAQ', 'MAQK', 'AQKS', 'QKSQ', 'KSQG'],
#  'S70': ['GAIE', 'AIEF', 'IEFD', 'EFDS', 'FDSG'],
#  'S71': ['GGPQ', 'GPQG', 'PQGI', 'QGIW', 'GIWG', 'IWGQ'],
#  'S72': ['GGPV', 'GPVP', 'PVPL', 'VPLS', 'PLSL', 'LSLV', 'SLVM'],
#  'S73': ['GGPL', 'GPLG', 'PLGV', 'LGVR', 'GVRG', 'VRGK'],
#  'S74': ['GGfP', 'GfPR', 'fPRS', 'PRSG', 'RSGG', 'SGGG'],
#  'S75': ['GSGS', 'SGSK', 'GSKI', 'SKII', 'KIIG', 'IIGG', 'IGGG'],
#  'S76': ['GPLG', 'PLGM', 'LGMR', 'GMRG'],
#  'S77': ['GAPF', 'APFE', 'PFEM', 'FEMS', 'EMSA', 'MSAG'],
#  'S79': ['GGPV', 'GPVG', 'PVGL', 'VGLI', 'GLIG'],
#  'S80': ['GGAA', 'GAAE', 'AAEA', 'AEAI', 'EAIS', 'AISD', 'ISDA'],
#  'S81': ['GGAQ', 'GAQP', 'AQPD', 'QPDA', 'PDAL', 'DALN', 'ALNV'],
#  'S82': ['GGDI', 'GDIV', 'DIVT', 'IVTV', 'VTVA', 'TVAN', 'VANA'],
#  'S83': ['GGDL', 'GDLG', 'DLGL', 'LGLK', 'GLKS', 'LKSV', 'KSVP'],
#  'S84': ['GGDV', 'GDVM', 'DVMA', 'VMAS', 'MASQ', 'ASQK', 'SQKR'],
#  'S85': ['GGES', 'GESD', 'ESDE', 'SDEL', 'DELQ', 'ELQT', 'LQTI'],
#  'S86': ['GGFH', 'GFHP', 'FHPL', 'HPLH', 'PLHS', 'LHSK', 'HSKI'],
#  'S87': ['GGGH', 'GGHA', 'GHAR', 'HARL', 'ARLV', 'RLVH', 'LVHV'],
#  'S88': ['GGHI', 'GHIA', 'HIAN', 'IANV', 'ANVE', 'NVER', 'VERV'],
#  'S89': ['GGKA', 'GKAA', 'KAAA', 'AAAT', 'AATQ', 'ATQK', 'TQKK'],
#  'S90': ['GGLA', 'GLAT', 'LATA', 'ATAS', 'TAST', 'ASTM', 'STMD'],
#  'S91': ['GGNL', 'GNLA', 'NLAG', 'LAGI', 'AGIL', 'GILK', 'ILKE'],
#  'S92': ['GGNP', 'GNPG', 'NPGM', 'PGMS', 'GMSE', 'MSEP', 'SEPV'],
#  'S93': ['GGPF', 'GPFG', 'PFGC', 'FGCH', 'GCHA', 'CHAK'],
#  'S94': ['GGPL', 'GPLG', 'PLGL', 'LGLR', 'GLRW', 'LRWW'],
#  'S95': ['GGQM', 'GQMG', 'QMGV', 'MGVM', 'GVMQ', 'VMQG', 'MQGV'],
#  'S96': ['GGQT', 'GQTC', 'QTCK', 'TCKC', 'CKCS', 'KCSC', 'CSCK'],
#  'S97': ['GGQW', 'GQWA', 'QWAG', 'WAGL', 'AGLV', 'GLVE', 'LVEK'],
#  'S98': ['GGRP', 'GRPA', 'RPAV', 'PAVM', 'AVMT', 'VMTS', 'MTSP'],
#  'S99': ['GGTL', 'GTLR', 'TLRE', 'LREL', 'RELH', 'ELHL', 'LHLD'],
#  'S100': ['GGTP', 'GTPP', 'TPPP', 'PPPS', 'PPSQ', 'PSQG', 'SQGK'],
#  'S101': ['GGTS', 'GTSE', 'TSED', 'SEDL', 'EDLV', 'DLVV', 'LVVQ'],
#  'S102': ['GGVW', 'GVWA', 'VWAA', 'WAAE', 'AAEA', 'AEAI', 'EAIS'],
#  'S104': ['GHSS', 'HSSK', 'SSKL', 'SKLQ', 'KLQG'],
#  'S105': ['GSSQ', 'SSQY', 'SQYS', 'QYSS', 'YSSN', 'SSNG', 'SNGG'],
#  'S106': ['GQKG', 'QKGR', 'KGRY', 'GRYK', 'RYKQ', 'YKQE', 'KQEG'],
#  'S107': ['GGKA', 'GKAF', 'KAFR', 'AFRR', 'FRRS', 'RRSG', 'RSGG'],
#  'S108': ['GAAN', 'AANL', 'ANLT', 'NLTR', 'LTRG'],
#  'S109': ['GGGE', 'GGEL', 'GELR', 'ELRG'],
#  'S111': ['GSPL',
#   'SPLA',
#   'PLAQ',
#   'LAQA',
#   'AQAV',
#   'QAVR',
#   'AVRS',
#   'VRSS',
#   'RSSG'],
#  'S112': ['GPVP', 'PVPL', 'VPLS', 'PLSL', 'LSLV', 'SLVM', 'LVMG'],
#  'S113': ['GSQP', 'SQPR', 'QPRI', 'PRIV', 'RIVG', 'IVGG', 'VGGG'],
#  'S114': ['GSYR', 'SYRI', 'YRIF', 'RIFG', 'IFGG'],
#  'S115': ['RPKP', 'PKPV', 'KPVE', 'PVEG', 'VEGG'],
#  'S117': ['GVPL', 'VPLS', 'PLSL', 'LSLT', 'SLTM', 'LTMG', 'TMGG'],
#  'S118': ['GAPF', 'APFE', 'PFEF', 'FEFS', 'EFSA', 'FSAG'],
#  'S119': ['GRPL', 'RPLA', 'PLAL', 'LALW', 'ALWR', 'LWRS', 'WRSG'],
#  'S120': ['GRPL', 'RPLA', 'PLAL', 'LALE', 'ALEE', 'LEES', 'EESQ', 'ESQG'],
#  'S121': ['GRPL', 'RPLA', 'PLAL', 'LALW', 'ALWR', 'LWRS', 'WRSQ', 'RSQG'],
#  'S122': ['GRNA',
#   'RNAL',
#   'NALA',
#   'ALAV',
#   'LAVE',
#   'AVER',
#   'VERT',
#   'ERTA',
#   'RTAS',
#   'TASG'],
#  'S124': ['GSGS',
#   'SGSN',
#   'GSNP',
#   'SNPY',
#   'NPYK',
#   'PYKY',
#   'YKYT',
#   'KYTA',
#   'YTAG'],
#  'S125': ['GSGS',
#   'SGSN',
#   'GSNP',
#   'SNPY',
#   'NPYG',
#   'PYGY',
#   'YGYT',
#   'GYTA',
#   'YTAG'],
#  'S126': ['GSGT',
#   'SGTL',
#   'GTLS',
#   'TLSE',
#   'LSEL',
#   'SELH',
#   'ELHT',
#   'LHTA',
#   'HTAG'],
#  'S127': ['GSGT',
#   'SGTI',
#   'GTIS',
#   'TISH',
#   'ISHL',
#   'SHLH',
#   'HLHT',
#   'LHTA',
#   'HTAG'],
#  'S130': ['GSGE',
#   'SGES',
#   'GESL',
#   'ESLA',
#   'SLAY',
#   'LAYY',
#   'AYYT',
#   'YYTA',
#   'YTAG'],
#  'S131': ['GSGH',
#   'SGHM',
#   'GHMH',
#   'HMHA',
#   'MHAA',
#   'HAAL',
#   'AALT',
#   'ALTA',
#   'LTAG'],
#  'S132': ['GSGK',
#   'SGKG',
#   'GKGP',
#   'KGPR',
#   'GPRQ',
#   'PRQI',
#   'RQIT',
#   'QITA',
#   'ITAG'],
#  'S133': ['GSGP',
#   'SGPL',
#   'GPLF',
#   'PLFY',
#   'LFYS',
#   'FYSV',
#   'YSVT',
#   'SVTA',
#   'VTAG'],
#  'S134': ['GSGR',
#   'SGRS',
#   'GRSE',
#   'RSEN',
#   'SENI',
#   'ENIR',
#   'NIRT',
#   'IRTA',
#   'RTAG'],
#  'S135': ['GGPW', 'GPWG', 'PWGI', 'WGIW', 'GIWG', 'IWGQ', 'WGQG'],
#  'S138': ['GGHP', 'GHPG', 'HPGG', 'PGGP', 'GGPQ', 'GPQG'],
#  'S139': ['GGGV', 'GGVF', 'GVFR', 'VFRM', 'FRML', 'RMLS', 'MLSV', 'LSVG'],
#  'S140': ['GGGL', 'GGLF', 'GLFR', 'LFRS', 'FRSL', 'RSLS', 'SLSS', 'LSSG'],
#  'S141': ['GGGL', 'GGLL', 'GLLY', 'LLYG', 'LYGK', 'YGKG', 'GKGG'],
#  'S143': ['GGIP',
#   'GIPS',
#   'IPSI',
#   'PSIQ',
#   'SIQS',
#   'IQSR',
#   'QSRG',
#   'SRGL',
#   'RGLG'],
#  'S144': ['GGNL',
#   'GNLA',
#   'NLAR',
#   'LARA',
#   'ARAL',
#   'RALK',
#   'ALKQ',
#   'LKQT',
#   'KQTI',
#   'QTIG'],
#  'S145': ['GGHM',
#   'GHMV',
#   'HMVQ',
#   'MVQH',
#   'VQHL',
#   'QHLI',
#   'HLIQ',
#   'LIQW',
#   'IQWH',
#   'QWHG'],
#  'S147': ['GGTG', 'GTGP', 'TGPP', 'GPPG', 'PPGY', 'PGYT', 'GYTG'],
#  'S148': ['GGTG', 'GTGL', 'TGLP', 'GLPV', 'LPVY', 'PVYQ', 'VYQG'],
#  'S150': ['GGAA', 'GAAF', 'AAFA', 'AFAG']}

# %%
# Retrieve relevant kmer_overlap for k=4, keys are kmers of length k=4 and keys are all substrates in the database containing said kmer
data.get_kmer_overlap(4)
# Out:
# {'AAAT': ['S89'],
#  'AAEA': ['S80', 'S102'],
#  'AAFA': ['S150'],
#  'AAKG': ['S31'],
#  'AALI': ['S37', 'S43'],
#  'AALT': ['S131'],
#  'AANL': ['S108'],
#  'AATQ': ['S89'],
#  'AEAI': ['S80', 'S102'],
#  'AEQQ': ['S67', 'S68'],
#  'AFAG': ['S150'],
#  'AFRR': ['S107'],
#  'AFRS': ['S23'],
#  'AGAG': ['S6'],
#  'AGGA': ['S52'],
#  'AGIL': ['S91'],
#  'AGLV': ['S97'],
#  'AGPR': ['S31'],
#  'AGgG': ['S41'],
#  'AIEF': ['S70'],
#  'AISD': ['S80'],
#  'AKIR': ['S32', 'S33'],
#  'AKKG': ['S32'],
#  'ALAV': ['S122'],
#  'ALEE': ['S120'],
#  'ALEK': ['S26'],
#  'ALIT': ['S43'],
#  'ALIV': ['S37'],
#  'ALKQ': ['S144'],
#  'ALLR': ['S63'],
#  'ALNV': ['S81'],
#  'ALTA': ['S131'],
#  'ALVP': ['S12'],
#  'ALWA': ['S11'],
#  'ALWE': ['S24'],
#  'ALWR': ['S119', 'S121'],
#  'AMWG': ['S5'],
#  'ANAK': ['S16'],
#  'ANLT': ['S108'],
#  'ANVE': ['S88'],
#  'APFE': ['S29', 'S77', 'S118'],
#  'AQAF': ['S23'],
#  'AQAV': ['S55', 'S111'],
#  'AQKS': ['S66', 'S69'],
#  'AQMG': ['S52'],
#  'AQPD': ['S81'],
#  'AQTL': ['S56'],
#  'ARAL': ['S144'],
#  'ARAV': ['S2'],
#  'ARDF': ['S21'],
#  'ARLV': ['S87'],
#  'ARQV': ['S14'],
#  'ARVV': ['S3', 'S15'],
#  'ASAS': ['S64'],
#  'ASQK': ['S84'],
#  'ASTM': ['S64', 'S90'],
#  'ATAS': ['S90'],
#  'ATDV': ['S53'],
#  'ATPK': ['S9'],
#  'ATQK': ['S89'],
#  'AVER': ['S122'],
#  'AVGG': ['S2'],
#  'AVMT': ['S98'],
#  'AVRS': ['S5', 'S55', 'S111'],
#  'AVTY': ['S34'],
#  'AYYT': ['S130'],
#  'CHAK': ['S93'],
#  'CKCS': ['S96'],
#  'CSCK': ['S96'],
#  'DALN': ['S81'],
#  'DDRR': ['S41'],
#  'DEKG': ['S21'],
#  'DELQ': ['S85'],
#  'DFFG': ['S21'],
#  'DIVT': ['S82'],
#  'DLGL': ['S83'],
#  'DLVV': ['S101'],
#  'DQMA': ['S66', 'S69'],
#  'DRMW': ['S39'],
#  'DRRA': ['S41'],
#  'DVMA': ['S84'],
#  'DVTT': ['S53'],
#  'DYQG': ['S60'],
#  'EAIS': ['S80', 'S102'],
#  'EAVR': ['S5'],
#  'EDLV': ['S101'],
#  'EESQ': ['S120'],
#  'EFDS': ['S70'],
#  'EFSA': ['S118'],
#  'EKGK': ['S21'],
#  'ELHL': ['S99'],
#  'ELHT': ['S126'],
#  'ELIQ': ['S44'],
#  'ELQT': ['S85'],
#  'ELRG': ['S109'],
#  'EMSA': ['S29', 'S77'],
#  'ENIR': ['S134'],
#  'EQQR': ['S67', 'S68'],
#  'ERMG': ['S58'],
#  'ERMM': ['S40'],
#  'ERTA': ['S122'],
#  'ESDE': ['S85'],
#  'ESLA': ['S130'],
#  'ESQG': ['S24', 'S120'],
#  'ETGE': ['S54'],
#  'ETRI': ['S10'],
#  'EWWM': ['S60', 'S62'],
#  'FDSG': ['S70'],
#  'FEFS': ['S118'],
#  'FEMS': ['S29', 'S77'],
#  'FGCH': ['S93'],
#  'FHPL': ['S86'],
#  'FKVV': ['S61'],
#  'FLRR': ['S61'],
#  'FLRT': ['S38'],
#  'FNTE': ['S9'],
#  'FNYL': ['S30'],
#  'FRML': ['S139'],
#  'FRNA': ['S6'],
#  'FRRS': ['S107'],
#  'FRSG': ['S23'],
#  'FRSL': ['S140'],
#  'FRVG': ['S7'],
#  'FSAG': ['S118'],
#  'FYSV': ['S133'],
#  'GAAE': ['S80'],
#  'GAAF': ['S150'],
#  'GAAN': ['S108'],
#  'GAGG': ['S52'],
#  'GAGP': ['S31'],
#  'GAIE': ['S70'],
#  'GAKI': ['S32', 'S33'],
#  'GALL': ['S63'],
#  'GALV': ['S12'],
#  'GAPF': ['S29', 'S77', 'S118'],
#  'GAQM': ['S52'],
#  'GAQP': ['S81'],
#  'GATD': ['S53'],
#  'GATP': ['S9'],
#  'GCHA': ['S93'],
#  'GDEK': ['S21'],
#  'GDIV': ['S82'],
#  'GDLG': ['S83'],
#  'GDQM': ['S66', 'S69'],
#  'GDRM': ['S39'],
#  'GDVM': ['S84'],
#  'GELI': ['S44'],
#  'GELR': ['S109'],
#  'GERM': ['S40'],
#  'GESD': ['S85'],
#  'GESL': ['S130'],
#  'GETR': ['S10'],
#  'GEWW': ['S60'],
#  'GFEG': ['S10'],
#  'GFHP': ['S86'],
#  'GFLR': ['S61'],
#  'GFRN': ['S6'],
#  'GFRV': ['S7'],
#  'GGAA': ['S80', 'S150'],
#  'GGAG': ['S52'],
#  'GGAP': ['S29'],
#  'GGAQ': ['S52', 'S81'],
#  'GGAT': ['S53'],
#  'GGDI': ['S82'],
#  'GGDL': ['S83'],
#  'GGDV': ['S84'],
#  'GGEL': ['S109'],
#  'GGES': ['S85'],
#  'GGFH': ['S86'],
#  'GGGA': ['S29'],
#  'GGGE': ['S109'],
#  'GGGG': ['S59'],
#  'GGGH': ['S87'],
#  'GGGL': ['S140', 'S141'],
#  'GGGP': ['S57', 'S59'],
#  'GGGS': ['S16'],
#  'GGGV': ['S139'],
#  'GGHA': ['S87'],
#  'GGHI': ['S88'],
#  'GGHM': ['S145'],
#  'GGHP': ['S42', 'S138'],
#  'GGIP': ['S143'],
#  'GGKA': ['S89', 'S107'],
#  'GGKG': ['S28', 'S65'],
#  'GGLA': ['S90'],
#  'GGLF': ['S140'],
#  'GGLG': ['S51'],
#  'GGLL': ['S141'],
#  'GGLS': ['S54'],
#  'GGLV': ['S13'],
#  'GGNL': ['S91', 'S144'],
#  'GGNP': ['S92'],
#  'GGPF': ['S93'],
#  'GGPG': ['S59'],
#  'GGPL': ['S57', 'S73', 'S94'],
#  'GGPP': ['S28'],
#  'GGPQ': ['S71', 'S138'],
#  'GGPV': ['S72', 'S79'],
#  'GGPW': ['S135'],
#  'GGQG': ['S45'],
#  'GGQM': ['S95'],
#  'GGQT': ['S96'],
#  'GGQW': ['S97'],
#  'GGRI': ['S38'],
#  'GGRK': ['S20'],
#  'GGRP': ['S98'],
#  'GGSG': ['S16', 'S20'],
#  'GGTG': ['S147', 'S148'],
#  'GGTL': ['S99'],
#  'GGTP': ['S100'],
#  'GGTS': ['S101'],
#  'GGVF': ['S139'],
#  'GGVP': ['S17'],
#  'GGVW': ['S102'],
#  'GGfP': ['S74'],
#  'GHAR': ['S87'],
#  'GHGD': ['S66'],
#  'GHIA': ['S88'],
#  'GHMH': ['S131'],
#  'GHMV': ['S145'],
#  'GHPG': ['S42', 'S138'],
#  'GHSS': ['S104'],
#  'GIKP': ['S49'],
#  'GILK': ['S91'],
#  'GILS': ['S19'],
#  'GIPS': ['S143'],
#  'GIQQ': ['S27'],
#  'GIWG': ['S71', 'S135'],
#  'GKAA': ['S89'],
#  'GKAF': ['S107'],
#  'GKAR': ['S21'],
#  'GKGG': ['S28', 'S141'],
#  'GKGP': ['S132'],
#  'GKGR': ['S65'],
#  'GKLR': ['S42'],
#  'GKPI': ['S22'],
#  'GLAQ': ['S23'],
#  'GLAR': ['S57'],
#  'GLAS': ['S64'],
#  'GLAT': ['S90'],
#  'GLFR': ['S140'],
#  'GLGA': ['S63'],
#  'GLGP': ['S51'],
#  'GLIG': ['S79'],
#  'GLKS': ['S83'],
#  'GLLY': ['S47', 'S141'],
#  'GLPV': ['S148'],
#  'GLQA': ['S15'],
#  'GLRG': ['S8', 'S28'],
#  'GLRS': ['S4'],
#  'GLRW': ['S94'],
#  'GLSL': ['S54', 'S65'],
#  'GLVE': ['S97'],
#  'GLVP': ['S13'],
#  'GMAA': ['S37', 'S43'],
#  'GMER': ['S58'],
#  'GMRG': ['S76'],
#  'GMSE': ['S92'],
#  'GNIP': ['S47'],
#  'GNLA': ['S91', 'S144'],
#  'GNPG': ['S92'],
#  'GNSG': ['S34'],
#  'GPFG': ['S93'],
#  'GPGG': ['S59'],
#  'GPKG': ['S51'],
#  'GPLA': ['S11'],
#  'GPLF': ['S133'],
#  'GPLG': ['S4', 'S7', 'S8', 'S57', 'S73', 'S76', 'S94'],
#  'GPMK': ['S50'],
#  'GPPG': ['S147'],
#  'GPPP': ['S28'],
#  'GPQG': ['S48', 'S71', 'S138'],
#  'GPRK': ['S31'],
#  'GPRP': ['S30'],
#  'GPRQ': ['S132'],
#  'GPVG': ['S79'],
#  'GPVP': ['S72', 'S112'],
#  'GPWG': ['S135'],
#  'GQAK': ['S33'],
#  'GQKG': ['S106'],
#  'GQMG': ['S95'],
#  'GQTC': ['S96'],
#  'GQTG': ['S51'],
#  'GQWA': ['S97'],
#  'GRAE': ['S67', 'S68'],
#  'GRAV': ['S34'],
#  'GRGL': ['S65'],
#  'GRIF': ['S38'],
#  'GRIV': ['S48'],
#  'GRKR': ['S20'],
#  'GRNA': ['S122'],
#  'GRPA': ['S98'],
#  'GRPE': ['S62'],
#  'GRPK': ['S36'],
#  'GRPL': ['S24', 'S119', 'S120', 'S121'],
#  'GRQA': ['S2', 'S14'],
#  'GRQR': ['S1', 'S26'],
#  'GRQS': ['S18'],
#  'GRRA': ['S3'],
#  'GRSA': ['S16'],
#  'GRSE': ['S134'],
#  'GRYK': ['S106'],
#  'GSAG': ['S12'],
#  'GSGD': ['S39'],
#  'GSGE': ['S40', 'S130'],
#  'GSGH': ['S131'],
#  'GSGK': ['S132'],
#  'GSGP': ['S133'],
#  'GSGR': ['S16', 'S134'],
#  'GSGS': ['S75', 'S124', 'S125'],
#  'GSGT': ['S126', 'S127'],
#  'GSKI': ['S75'],
#  'GSNL': ['S45'],
#  'GSNP': ['S124', 'S125'],
#  'GSPL': ['S55', 'S111'],
#  'GSQP': ['S113'],
#  'GSSM': ['S56'],
#  'GSSQ': ['S105'],
#  'GSYR': ['S114'],
#  'GTGL': ['S148'],
#  'GTGP': ['S147'],
#  'GTIS': ['S127'],
#  'GTLR': ['S99'],
#  'GTLS': ['S126'],
#  'GTPP': ['S100'],
#  'GTSE': ['S101'],
#  'GTYS': ['S35'],
#  'GVFR': ['S139'],
#  'GVGR': ['S62'],
#  'GVMQ': ['S95'],
#  'GVPL': ['S117'],
#  'GVPR': ['S17'],
#  'GVRG': ['S73'],
#  'GVWA': ['S102'],
#  'GWEA': ['S5'],
#  'GWIG': ['S6'],
#  'GYQI': ['S46'],
#  'GYTA': ['S125'],
#  'GYTG': ['S147'],
#  'GfPR': ['S74'],
#  'GsDD': ['S41'],
#  'HAAL': ['S131'],
#  'HARL': ['S87'],
#  'HGDQ': ['S66'],
#  'HIAN': ['S88'],
#  'HLHT': ['S127'],
#  'HLIQ': ['S145'],
#  'HMHA': ['S131'],
#  'HMVQ': ['S145'],
#  'HPGG': ['S138'],
#  'HPLH': ['S86'],
#  'HSKI': ['S86'],
#  'HSSK': ['S104'],
#  'HTAG': ['S126', 'S127'],
#  'IANV': ['S88'],
#  'IEFD': ['S70'],
#  'IFGG': ['S114'],
#  'IFLR': ['S38'],
#  'IFNT': ['S9'],
#  'IGFR': ['S6'],
#  'IGGG': ['S75'],
#  'IIGG': ['S75'],
#  'IIKG': ['S10'],
#  'IKGF': ['S10'],
#  'IKPL': ['S46'],
#  'IKPR': ['S49'],
#  'ILKE': ['S91'],
#  'ILSR': ['S19'],
#  'IPMG': ['S47'],
#  'IPSI': ['S143'],
#  'IQQR': ['S27'],
#  'IQRN': ['S44'],
#  'IQSR': ['S143'],
#  'IQWH': ['S145'],
#  'IRGQ': ['S33'],
#  'IRKA': ['S32'],
#  'IRTA': ['S134'],
#  'ISDA': ['S80'],
#  'ISHL': ['S127'],
#  'ISLI': ['S22'],
#  'ISSG': ['S22'],
#  'ITAG': ['S132'],
#  'ITRP': ['S43'],
#  'IVGG': ['S18', 'S19', 'S45', 'S48', 'S49', 'S113'],
#  'IVRP': ['S37'],
#  'IVTV': ['S82'],
#  'IWGQ': ['S71', 'S135'],
#  'KAAA': ['S89'],
#  'KAAK': ['S31'],
#  'KAFR': ['S107'],
#  'KAKK': ['S32'],
#  'KARD': ['S21'],
#  'KCSC': ['S96'],
#  'KGFE': ['S10'],
#  'KGGP': ['S28'],
#  'KGKA': ['S21'],
#  'KGPR': ['S132'],
#  'KGQT': ['S51'],
#  'KGRG': ['S65'],
#  'KGRY': ['S106'],
#  'KIFN': ['S9'],
#  'KIIG': ['S75'],
#  'KIRG': ['S33'],
#  'KIRK': ['S32'],
#  'KLQG': ['S104'],
#  'KLRV': ['S42'],
#  'KPIS': ['S22'],
#  'KPLK': ['S46'],
#  'KPQQ': ['S36'],
#  'KPRI': ['S49'],
#  'KPVE': ['S115'],
#  'KQEG': ['S106'],
#  'KQTI': ['S144'],
#  'KRKV': ['S20'],
#  'KRLE': ['S63'],
#  'KRLT': ['S50'],
#  'KSQG': ['S69'],
#  'KSTD': ['S46'],
#  'KSVP': ['S83'],
#  'KVGG': ['S20'],
#  'KVVT': ['S61'],
#  'KYTA': ['S124'],
#  'LAGI': ['S91'],
#  'LALE': ['S120'],
#  'LALW': ['S11', 'S24', 'S119', 'S121'],
#  'LAQA': ['S23', 'S55', 'S111'],
#  'LARA': ['S144'],
#  'LARG': ['S57'],
#  'LASA': ['S64'],
#  'LATA': ['S90'],
#  'LAVE': ['S122'],
#  'LAYY': ['S130'],
#  'LEES': ['S120'],
#  'LEKG': ['S26'],
#  'LFRS': ['S140'],
#  'LFYS': ['S133'],
#  'LGAL': ['S63'],
#  'LGFR': ['S7'],
#  'LGGG': ['S27'],
#  'LGLA': ['S57'],
#  'LGLK': ['S83'],
#  'LGLR': ['S4', 'S8', 'S94'],
#  'LGMR': ['S76'],
#  'LGPK': ['S51'],
#  'LGVR': ['S73'],
#  'LHLD': ['S99'],
#  'LHSK': ['S86'],
#  'LHTA': ['S126', 'S127'],
#  'LIQR': ['S44'],
#  'LIQW': ['S145'],
#  'LISS': ['S22'],
#  'LITR': ['S43'],
#  'LIVR': ['S37'],
#  'LKQT': ['S144'],
#  'LKST': ['S46'],
#  'LKSV': ['S83'],
#  'LLRV': ['S63'],
#  'LLYG': ['S141'],
#  'LLYN': ['S47'],
#  'LPET': ['S54'],
#  'LPVY': ['S148'],
#  'LQAR': ['S15'],
#  'LQTI': ['S85'],
#  'LREL': ['S99'],
#  'LRGG': ['S28'],
#  'LRRQ': ['S61'],
#  'LRSS': ['S56'],
#  'LRSW': ['S4'],
#  'LRTA': ['S38'],
#  'LRVK': ['S63'],
#  'LRVV': ['S42'],
#  'LRWW': ['S94'],
#  'LSEL': ['S126'],
#  'LSLG': ['S65'],
#  'LSLP': ['S54'],
#  'LSLT': ['S117'],
#  'LSLV': ['S72', 'S112'],
#  'LSPA': ['S44'],
#  'LSRI': ['S19'],
#  'LSSG': ['S140'],
#  'LSVG': ['S139'],
#  'LTAG': ['S131'],
#  'LTLG': ['S50'],
#  'LTLR': ['S56'],
#  'LTMG': ['S117'],
#  'LTRG': ['S108'],
#  'LTRI': ['S45'],
#  'LVEK': ['S97'],
#  'LVHV': ['S87'],
#  'LVMG': ['S112'],
#  'LVPR': ['S12', 'S13'],
#  'LVVQ': ['S101'],
#  'LWAR': ['S11'],
#  'LWES': ['S24'],
#  'LWRS': ['S119', 'S121'],
#  'LYGK': ['S141'],
#  'LYNK': ['S47'],
#  'MAAL': ['S37', 'S43'],
#  'MAQK': ['S66', 'S69'],
#  'MAQT': ['S56'],
#  'MASQ': ['S84'],
#  'MDYQ': ['S60'],
#  'MERM': ['S58'],
#  'MGLL': ['S47'],
#  'MGVM': ['S95'],
#  'MGgG': ['S40'],
#  'MHAA': ['S131'],
#  'MKRL': ['S50'],
#  'MLSV': ['S139'],
#  'MMGg': ['S40'],
#  'MQGV': ['S95'],
#  'MSAG': ['S77'],
#  'MSEP': ['S92'],
#  'MTSP': ['S98'],
#  'MVQH': ['S145'],
#  'MWgg': ['S39'],
#  'NAGA': ['S6'],
#  'NAKG': ['S16'],
#  'NALA': ['S122'],
#  'NIPM': ['S47'],
#  'NIRT': ['S134'],
#  'NLAG': ['S91'],
#  'NLAR': ['S144'],
#  'NLSP': ['S44'],
#  'NLTR': ['S45', 'S108'],
#  'NPGM': ['S92'],
#  'NPYG': ['S125'],
#  'NPYK': ['S124'],
#  'NSGR': ['S34'],
#  'NTEG': ['S9'],
#  'NVER': ['S88'],
#  'NYLG': ['S30'],
#  'PAVM': ['S98'],
#  'PDAL': ['S81'],
#  'PDFG': ['S43'],
#  'PDLG': ['S37'],
#  'PETG': ['S54'],
#  'PEWW': ['S62'],
#  'PFEF': ['S118'],
#  'PFEM': ['S29', 'S77'],
#  'PFGC': ['S93'],
#  'PFNY': ['S30'],
#  'PGGP': ['S138'],
#  'PGMS': ['S92'],
#  'PGYT': ['S147'],
#  'PISL': ['S22'],
#  'PKGQ': ['S51'],
#  'PKIF': ['S9'],
#  'PKPQ': ['S36'],
#  'PKPV': ['S115'],
#  'PLAL': ['S11', 'S24', 'S119', 'S120', 'S121'],
#  'PLAQ': ['S55', 'S111'],
#  'PLFY': ['S133'],
#  'PLGF': ['S7'],
#  'PLGL': ['S4', 'S8', 'S57', 'S94'],
#  'PLGM': ['S76'],
#  'PLGV': ['S73'],
#  'PLHS': ['S86'],
#  'PLKS': ['S46'],
#  'PLSL': ['S72', 'S112', 'S117'],
#  'PMGL': ['S47'],
#  'PMKR': ['S50'],
#  'PPGY': ['S147'],
#  'PPPG': ['S28'],
#  'PPPP': ['S28'],
#  'PPPS': ['S100'],
#  'PPSQ': ['S100'],
#  'PQGI': ['S71'],
#  'PQGR': ['S48'],
#  'PQQF': ['S36'],
#  'PRGG': ['S17'],
#  'PRGS': ['S12', 'S13'],
#  'PRIV': ['S49', 'S113'],
#  'PRKA': ['S31'],
#  'PRPF': ['S30'],
#  'PRQI': ['S132'],
#  'PRSG': ['S74'],
#  'PSIQ': ['S143'],
#  'PSQG': ['S100'],
#  'PVEG': ['S115'],
#  'PVGL': ['S79'],
#  'PVPL': ['S72', 'S112'],
#  'PVYQ': ['S148'],
#  'PWGI': ['S135'],
#  'PYGY': ['S125'],
#  'PYKY': ['S124'],
#  'QAFR': ['S23'],
#  'QAKG': ['S33'],
#  'QARA': ['S2'],
#  'QARQ': ['S14'],
#  'QARV': ['S15'],
#  'QAVR': ['S55', 'S111'],
#  'QFKV': ['S61'],
#  'QFWG': ['S36'],
#  'QGIW': ['S71'],
#  'QGRI': ['S48'],
#  'QHLI': ['S145'],
#  'QIKP': ['S46'],
#  'QITA': ['S132'],
#  'QKGR': ['S106'],
#  'QKSQ': ['S69'],
#  'QMAQ': ['S66', 'S69'],
#  'QMGA': ['S52'],
#  'QMGV': ['S95'],
#  'QPDA': ['S81'],
#  'QPRI': ['S113'],
#  'QQFW': ['S36'],
#  'QQRL': ['S67', 'S68'],
#  'QQRS': ['S27'],
#  'QRLG': ['S68'],
#  'QRLK': ['S67'],
#  'QRNL': ['S44'],
#  'QRRA': ['S26'],
#  'QRRV': ['S1'],
#  'QRSL': ['S27'],
#  'QSRG': ['S143'],
#  'QSRI': ['S18'],
#  'QTCK': ['S96'],
#  'QTIG': ['S144'],
#  'QTLT': ['S56'],
#  'QVGG': ['S14'],
#  'QWAG': ['S97'],
#  'QWHG': ['S145'],
#  'QYSS': ['S105'],
#  'RAEQ': ['S67', 'S68'],
#  'RAGg': ['S41'],
#  'RALE': ['S26'],
#  'RALK': ['S144'],
#  'RARV': ['S3'],
#  'RAVG': ['S2'],
#  'RAVT': ['S34'],
#  'RDFF': ['S21'],
#  'RELH': ['S99'],
#  'RGGK': ['S28'],
#  'RGLG': ['S143'],
#  'RGLS': ['S65'],
#  'RGQA': ['S33'],
#  'RGSA': ['S12'],
#  'RGSG': ['S13'],
#  'RIFG': ['S114'],
#  'RIFL': ['S38'],
#  'RIIK': ['S10'],
#  'RIVG': ['S18', 'S19', 'S45', 'S48', 'S49', 'S113'],
#  'RKAA': ['S31'],
#  'RKAK': ['S32'],
#  'RKRK': ['S20'],
#  'RKVG': ['S20'],
#  'RLKG': ['S67'],
#  'RLTL': ['S50'],
#  'RLVH': ['S87'],
#  'RMGG': ['S58'],
#  'RMLS': ['S139'],
#  'RMMG': ['S40'],
#  'RMWg': ['S39'],
#  'RNAG': ['S6'],
#  'RNAL': ['S122'],
#  'RNLS': ['S44'],
#  'RPAV': ['S98'],
#  'RPDF': ['S43'],
#  'RPDL': ['S37'],
#  'RPEW': ['S62'],
#  'RPFN': ['S30'],
#  'RPKP': ['S36', 'S115'],
#  'RPLA': ['S24', 'S119', 'S120', 'S121'],
#  'RQAR': ['S2', 'S14'],
#  'RQFK': ['S61'],
#  'RQIT': ['S132'],
#  'RQRR': ['S1', 'S26'],
#  'RQSR': ['S18'],
#  'RQVG': ['S14'],
#  'RRAG': ['S41'],
#  'RRAL': ['S26'],
#  'RRAR': ['S3'],
#  'RRQF': ['S61'],
#  'RRSG': ['S107'],
#  'RRVV': ['S1'],
#  'RSAM': ['S5'],
#  'RSAN': ['S16'],
#  'RSEN': ['S134'],
#  'RSGG': ['S74', 'S107'],
#  'RSLG': ['S27'],
#  'RSLS': ['S140'],
#  'RSQG': ['S121'],
#  'RSRY': ['S35'],
#  'RSSG': ['S111'],
#  'RSSS': ['S55', 'S56'],
#  'RSWG': ['S4'],
#  'RTAG': ['S38', 'S134'],
#  'RTAS': ['S122'],
#  'RVKR': ['S63'],
#  'RVVG': ['S1', 'S3', 'S15', 'S42'],
#  'RYKQ': ['S106'],
#  'RYLG': ['S35'],
#  'SAMW': ['S5'],
#  'SANA': ['S16'],
#  'SAST': ['S64'],
#  'SDEL': ['S85'],
#  'SEDL': ['S101'],
#  'SELH': ['S126'],
#  'SENI': ['S134'],
#  'SEPV': ['S92'],
#  'SGDR': ['S39'],
#  'SGER': ['S40'],
#  'SGES': ['S130'],
#  'SGGG': ['S74'],
#  'SGHM': ['S131'],
#  'SGKG': ['S132'],
#  'SGPL': ['S133'],
#  'SGRA': ['S34'],
#  'SGRS': ['S16', 'S134'],
#  'SGSK': ['S75'],
#  'SGSN': ['S124', 'S125'],
#  'SGTI': ['S127'],
#  'SGTL': ['S126'],
#  'SHLH': ['S127'],
#  'SIQS': ['S143'],
#  'SKII': ['S75'],
#  'SKLQ': ['S104'],
#  'SLAY': ['S130'],
#  'SLGG': ['S27'],
#  'SLIS': ['S22'],
#  'SLPE': ['S54'],
#  'SLSS': ['S140'],
#  'SLTM': ['S117'],
#  'SLVM': ['S72', 'S112'],
#  'SMAQ': ['S56'],
#  'SNGG': ['S105'],
#  'SNLT': ['S45'],
#  'SNPY': ['S124', 'S125'],
#  'SPAG': ['S44'],
#  'SPLA': ['S55', 'S111'],
#  'SQGK': ['S100'],
#  'SQKR': ['S84'],
#  'SQPR': ['S113'],
#  'SQYS': ['S105'],
#  'SRGL': ['S143'],
#  'SRIV': ['S18', 'S19'],
#  'SRSR': ['S35'],
#  'SRYL': ['S35'],
#  'SSKL': ['S104'],
#  'SSMA': ['S56'],
#  'SSNG': ['S105'],
#  'SSQY': ['S105'],
#  'STDG': ['S46'],
#  'STMD': ['S64', 'S90'],
#  'SVTA': ['S133'],
#  'SYRI': ['S114'],
#  'TASG': ['S122'],
#  'TAST': ['S90'],
#  'TCKC': ['S96'],
#  'TDVT': ['S53'],
#  'TGLP': ['S148'],
#  'TGPP': ['S147'],
#  'TISH': ['S127'],
#  'TLRE': ['S99'],
#  'TLRS': ['S56'],
#  'TLSE': ['S126'],
#  'TLTL': ['S56'],
#  'TMDG': ['S64'],
#  'TMGG': ['S117'],
#  'TPKI': ['S9'],
#  'TPPP': ['S100'],
#  'TQKK': ['S89'],
#  'TRII': ['S10'],
#  'TRIV': ['S45'],
#  'TRPD': ['S43'],
#  'TSED': ['S101'],
#  'TTTP': ['S53'],
#  'TVAN': ['S82'],
#  'TYSR': ['S35'],
#  'VANA': ['S82'],
#  'VEGG': ['S115'],
#  'VERT': ['S122'],
#  'VERV': ['S88'],
#  'VFRM': ['S139'],
#  'VGGG': ['S18', 'S19', 'S113'],
#  'VGGH': ['S42'],
#  'VGGQ': ['S45'],
#  'VGGS': ['S20'],
#  'VGLI': ['S79'],
#  'VGRP': ['S62'],
#  'VKRL': ['S63'],
#  'VMAS': ['S84'],
#  'VMQG': ['S95'],
#  'VMTS': ['S98'],
#  'VPLS': ['S72', 'S112', 'S117'],
#  'VPRG': ['S12', 'S13', 'S17'],
#  'VQHL': ['S145'],
#  'VRGK': ['S73'],
#  'VRPD': ['S37'],
#  'VRSA': ['S5'],
#  'VRSS': ['S55', 'S111'],
#  'VTAG': ['S133'],
#  'VTTT': ['S53'],
#  'VTVA': ['S82'],
#  'VTYG': ['S34'],
#  'VVGG': ['S1', 'S3', 'S15', 'S42'],
#  'VWAA': ['S102'],
#  'VYQG': ['S148'],
#  'WAAE': ['S102'],
#  'WAGL': ['S97'],
#  'WARG': ['S11'],
#  'WEAV': ['S5'],
#  'WESQ': ['S24'],
#  'WGIW': ['S135'],
#  'WGQG': ['S135'],
#  'WIGF': ['S6'],
#  'WMDG': ['S62'],
#  'WMDY': ['S60'],
#  'WRSG': ['S119'],
#  'WRSQ': ['S121'],
#  'WWMD': ['S60', 'S62'],
#  'WggG': ['S39'],
#  'YGKG': ['S141'],
#  'YGYT': ['S125'],
#  'YKQE': ['S106'],
#  'YKYT': ['S124'],
#  'YNKG': ['S47'],
#  'YQIK': ['S46'],
#  'YRIF': ['S114'],
#  'YSRS': ['S35'],
#  'YSSN': ['S105'],
#  'YSVT': ['S133'],
#  'YTAG': ['S124', 'S125', 'S130'],
#  'YYTA': ['S130'],
#  'fPRS': ['S74'],
#  'sDDR': ['S41']}

# %%
# Summarize relevant kmer data
# TO DO: Add column with which substartes
kmer_f_sorted, kmer_f_sorted_filtered = data.summarize_kmer(kmer_len = 4, top_k = 20)
display(kmer_f_sorted_filtered)
# Out:
#       Frequency
# GPLG          7
# RIVG          6
# IVGG          6
# PLAL          5
# LALW          4
# RPLA          4
# PLGL          4
# VVGG          4
# GRPL          4
# RVVG          4
# APFE          3
# VPRG          3
# GPQG          3
# VPLS          3
# GAPF          3
# VGGG          3
# LAQA          3
# GSGS          3
# GGPL          3
# AVRS          3

# %%
# Search example kmer of interest 'PLGL' using search_kmer() 
print('Queried kmer:')
print('PLGL')
print('\n')
PLGL_info = data.search_kmer('PLGL', True, data.aa_dict)
print(PLGL_info)
# Out:
# Queried kmer:
# PLGL
#
#
# S4:GPLGLRSWG - GPLGLRSWG
#
# S8:GPLGLRG - GPLGLRG
#
# S57:GGGPLGLARG - GGGPLGLARG
#
# S94:GGPLGLRWW - GGPLGLRWW
#
#   Peptide    Sequence
# 0      S4   GPLGLRSWG
# 1      S8     GPLGLRG
# 2     S57  GGGPLGLARG
# 3     S94   GGPLGLRWW
